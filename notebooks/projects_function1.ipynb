# %%
def load_and_process(filing_counts):
    df = (
    pd.read_csv('filing_counts.csv')   
    .drop('for_total',axis=1)
    .drop('case_action',axis=1)
    .assign(state_agegroup=lambda x: x['age_group']+x['state'])
)

    return df
df.head(20)
# Out:
#        state  year             case_type      age_group  count  \
# 0     Alaska  2020             G+C+Joint  Adults+Minors   1171
# 1     Alaska  2019             G+C+Joint  Adults+Minors   1084
# 2     Alaska  2018             G+C+Joint  Adults+Minors   1227
# 3     Alaska  2017             G+C+Joint  Adults+Minors   1090
# 4    Arizona  2020     Guardianship ONLY    Adults ONLY   2520
# 5    Arizona  2020     Guardianship ONLY    Minors ONLY   2871
# 6    Arizona  2020  Conservatorship ONLY    Adults ONLY   3485
# 7    Arizona  2020  Conservatorship ONLY    Minors ONLY   1365
# 8    Arizona  2019     Guardianship ONLY    Adults ONLY   2383
# 9    Arizona  2019     Guardianship ONLY    Minors ONLY   3608
# 10   Arizona  2019  Conservatorship ONLY    Adults ONLY   4003
# 11   Arizona  2019  Conservatorship ONLY    Minors ONLY   1334
# 12   Arizona  2018     Guardianship ONLY    Adults ONLY   2800
# 13   Arizona  2018     Guardianship ONLY    Minors ONLY   3785
# 14   Arizona  2018  Conservatorship ONLY    Adults ONLY   4554
# 15   Arizona  2018  Conservatorship ONLY    Minors ONLY   1361
# 16  Arkansas  2020             G+C+Joint    Adults ONLY   1110
# 17  Arkansas  2020             G+C+Joint    Minors ONLY   2439
# 18  Arkansas  2020             G+C+Joint  Adults+Minors    133
# 19  Arkansas  2019             G+C+Joint    Adults ONLY   1164
#
#            state_agegroup
# 0     Adults+MinorsAlaska
# 1     Adults+MinorsAlaska
# 2     Adults+MinorsAlaska
# 3     Adults+MinorsAlaska
# 4      Adults ONLYArizona
# 5      Minors ONLYArizona
# 6      Adults ONLYArizona
# 7      Minors ONLYArizona
# 8      Adults ONLYArizona
# 9      Minors ONLYArizona
# 10     Adults ONLYArizona
# 11     Minors ONLYArizona
# 12     Adults ONLYArizona
# 13     Minors ONLYArizona
# 14     Adults ONLYArizona
# 15     Minors ONLYArizona
# 16    Adults ONLYArkansas
# 17    Minors ONLYArkansas
# 18  Adults+MinorsArkansas
# 19    Adults ONLYArkansas
